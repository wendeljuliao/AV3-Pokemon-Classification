# %% [markdown]
# #### IMPORTANTO BIBLIOTECAS

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow import keras

# %% [markdown]
# #### VERIFICANDO O RECONHECIMENTO DA GPU

# %%
# DESCOMENTAR PARA FORÇAR A RODAR EM CPU
#import os

#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) > 0:
   tf.config.experimental.set_memory_growth(physical_devices[0], True) #necessário para a CNN

print('tf version: ',tf.__version__)
print ('num gpus: ',len(physical_devices))
# Out:
# tf version:  2.6.0
# num gpus:  1
# 2023-05-11 20:26:34.943221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:34.967529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:34.967699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# #### CARREGANDO CONJUNTO DE DADOS

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
y_test[0]
# Out:
# 9

# %% [markdown]
# #### SEPARANDO CONJUNTO DE TREINO E VALIDAÇÃO

# %%
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

X_test = X_test / 255.0

# DESCOMENTAR PARA REDES CONVOLUCIONAIS
# X_train = np.expand_dims(X_train, -1)
# X_test = np.expand_dims(X_test, -1)
# X_valid = np.expand_dims(X_valid, -1)

# %% [markdown]
# #### CRIANDO HASH PARA IMPRIMIR O NOME DAS CLASSES

# %%
class_names = ["Camiseta/Top", "Calça", "Suéter", "Vestido", "Casaco",
"Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]

# %%
class_names[y_train[0]]
# Out:
# 'Casaco'

# %% [markdown]
# #### VISUALIZANDO IMAGENS DO CONJUNTO DE DADOS

# %%
plt.figure(figsize=(10,10))
for i in range(30):
    plt.subplot(6,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# #### INSTACIANDO MODELO

# %%
model = keras.models.Sequential([
    
########## MLP    
keras.layers.Flatten(input_shape=[28, 28]),
#keras.layers.Dense(9000, activation="relu"),
#keras.layers.Dense(3000, activation="relu"),
#keras.layers.Dense(1000, activation="relu"),
keras.layers.Dense(300, activation="relu"),
keras.layers.Dense(100, activation="relu"),

########## LSTM
# keras.layers.LSTM(784, activation='relu', input_shape=[28, 28]),
    
########## Stacked LSTM
# keras.layers.LSTM(784, activation='relu', return_sequences=True, input_shape=[28, 28]),
# keras.layers.LSTM(250, activation='relu', return_sequences=True),
# keras.layers.LSTM(90, activation='relu', return_sequences=True),
# keras.layers.LSTM(30, activation='relu'),
    
########## Bidirectional LSTM
# keras.layers.Bidirectional(keras.layers.LSTM(100, activation='relu'), input_shape=[28, 28]),
    
########## Conv
# keras.Input(shape=[28,28,1]),
# keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
# keras.layers.MaxPooling2D(pool_size=(2, 2)),
# keras.layers.Conv2D(64, kernel_size=(2, 2), activation="relu"),
# keras.layers.MaxPooling2D(pool_size=(2, 2)),
# keras.layers.Flatten(),
# keras.layers.Dense(100, activation="relu"),
    
    
keras.layers.Dense(10, activation="softmax")
])
# Out:
# 2023-05-11 20:26:36.149139: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 20:26:36.149879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.150066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.150166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.497272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.497432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.497536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-11 20:26:36.497620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4345 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### COMPILANDO MODELO

# %%
model.compile(loss="sparse_categorical_crossentropy",
optimizer="sgd",
metrics=["accuracy"])

# %% [markdown]
# #### TREINANDO MODELO

# %%
#callbacks = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')]

#callbacks.append(tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=0, restore_best_weights=True))


history = model.fit(X_train, y_train, epochs=50,
                    validation_data=(X_valid, y_valid),
                    #callbacks=callbacks
                   )
# Out:
# 2023-05-11 20:26:36.737379: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 1719/1719 [==============================] - 2s 990us/step - loss: 0.7152 - accuracy: 0.7690 - val_loss: 0.5001 - val_accuracy: 0.8334
# Epoch 2/50
# 1719/1719 [==============================] - 2s 946us/step - loss: 0.4843 - accuracy: 0.8295 - val_loss: 0.4353 - val_accuracy: 0.8498
# Epoch 3/50
# 1719/1719 [==============================] - 2s 938us/step - loss: 0.4389 - accuracy: 0.8453 - val_loss: 0.4289 - val_accuracy: 0.8480
# Epoch 4/50
# 1719/1719 [==============================] - 2s 939us/step - loss: 0.4111 - accuracy: 0.8548 - val_loss: 0.3845 - val_accuracy: 0.8696
# Epoch 5/50
# 1719/1719 [==============================] - 2s 938us/step - loss: 0.3910 - accuracy: 0.8614 - val_loss: 0.3721 - val_accuracy: 0.8702
# Epoch 6/50
# 1719/1719 [==============================] - 2s 895us/step - loss: 0.3749 - accuracy: 0.8671 - val_loss: 0.3943 - val_accuracy: 0.8618
# Epoch 7/50
# 1719/1719 [==============================] - 2s 920us/step - loss: 0.3613 - accuracy: 0.8720 - val_loss: 0.3617 - val_accuracy: 0.8756
# Epoch 8/50
# 1719/1719 [==============================] - 2s 903us/step - loss: 0.3495 - accuracy: 0.8757 - val_loss: 0.3683 - val_accuracy: 0.8710
# Epoch 9/50
# 1719/1719 [==============================] - 2s 922us/step - loss: 0.3388 - accuracy: 0.8797 - val_loss: 0.3569 - val_accuracy: 0.8766
# Epoch 10/50
# 1719/1719 [==============================] - 2s 914us/step - loss: 0.3302 - accuracy: 0.8827 - val_loss: 0.3566 - val_accuracy: 0.8750
# Epoch 11/50
# 1719/1719 [==============================] - 2s 913us/step - loss: 0.3209 - accuracy: 0.8863 - val_loss: 0.3422 - val_accuracy: 0.8780
# Epoch 12/50
# 1719/1719 [==============================] - 2s 914us/step - loss: 0.3140 - accuracy: 0.8878 - val_loss: 0.3258 - val_accuracy: 0.8842
# Epoch 13/50
# 1719/1719 [==============================] - 2s 917us/step - loss: 0.3067 - accuracy: 0.8907 - val_loss: 0.3309 - val_accuracy: 0.8810
# Epoch 14/50
# 1719/1719 [==============================] - 2s 951us/step - loss: 0.2989 - accuracy: 0.8939 - val_loss: 0.3230 - val_accuracy: 0.8880
# Epoch 15/50
# 1719/1719 [==============================] - 2s 924us/step - loss: 0.2928 - accuracy: 0.8955 - val_loss: 0.3404 - val_accuracy: 0.8814
# Epoch 16/50
# 1719/1719 [==============================] - 2s 930us/step - loss: 0.2870 - accuracy: 0.8981 - val_loss: 0.3372 - val_accuracy: 0.8808
# Epoch 17/50
# 1719/1719 [==============================] - 2s 925us/step - loss: 0.2810 - accuracy: 0.8986 - val_loss: 0.3138 - val_accuracy: 0.8896
# Epoch 18/50
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2755 - accuracy: 0.9009 - val_loss: 0.3054 - val_accuracy: 0.8928
# Epoch 19/50
# 1719/1719 [==============================] - 2s 960us/step - loss: 0.2709 - accuracy: 0.9027 - val_loss: 0.3084 - val_accuracy: 0.8876
# Epoch 20/50
# 1719/1719 [==============================] - 2s 928us/step - loss: 0.2654 - accuracy: 0.9048 - val_loss: 0.3074 - val_accuracy: 0.8920
# Epoch 21/50
# 1719/1719 [==============================] - 2s 922us/step - loss: 0.2608 - accuracy: 0.9070 - val_loss: 0.3023 - val_accuracy: 0.8932
# Epoch 22/50
# 1719/1719 [==============================] - 2s 922us/step - loss: 0.2560 - accuracy: 0.9082 - val_loss: 0.2994 - val_accuracy: 0.8938
# Epoch 23/50
# 1719/1719 [==============================] - 2s 921us/step - loss: 0.2515 - accuracy: 0.9095 - val_loss: 0.3212 - val_accuracy: 0.8860
# Epoch 24/50
# 1719/1719 [==============================] - 2s 976us/step - loss: 0.2473 - accuracy: 0.9108 - val_loss: 0.3145 - val_accuracy: 0.8862
# Epoch 25/50
# 1719/1719 [==============================] - 2s 939us/step - loss: 0.2432 - accuracy: 0.9124 - val_loss: 0.3041 - val_accuracy: 0.8928
# Epoch 26/50
# 1719/1719 [==============================] - 2s 899us/step - loss: 0.2385 - accuracy: 0.9151 - val_loss: 0.3086 - val_accuracy: 0.8860
# Epoch 27/50
# 1719/1719 [==============================] - 2s 895us/step - loss: 0.2348 - accuracy: 0.9159 - val_loss: 0.2976 - val_accuracy: 0.8938
# Epoch 28/50
# 1719/1719 [==============================] - 2s 925us/step - loss: 0.2307 - accuracy: 0.9160 - val_loss: 0.2984 - val_accuracy: 0.8954
# Epoch 29/50
# 1719/1719 [==============================] - 2s 920us/step - loss: 0.2279 - accuracy: 0.9177 - val_loss: 0.3043 - val_accuracy: 0.8920
# Epoch 30/50
# 1719/1719 [==============================] - 2s 913us/step - loss: 0.2240 - accuracy: 0.9183 - val_loss: 0.2934 - val_accuracy: 0.8932
# Epoch 31/50
# 1719/1719 [==============================] - 2s 918us/step - loss: 0.2203 - accuracy: 0.9208 - val_loss: 0.2989 - val_accuracy: 0.8970
# Epoch 32/50
# 1719/1719 [==============================] - 2s 911us/step - loss: 0.2168 - accuracy: 0.9221 - val_loss: 0.2856 - val_accuracy: 0.8954
# Epoch 33/50
# 1719/1719 [==============================] - 2s 919us/step - loss: 0.2130 - accuracy: 0.9235 - val_loss: 0.2863 - val_accuracy: 0.8996
# Epoch 34/50
# 1719/1719 [==============================] - 2s 913us/step - loss: 0.2108 - accuracy: 0.9241 - val_loss: 0.2955 - val_accuracy: 0.8896
# Epoch 35/50
# 1719/1719 [==============================] - 2s 911us/step - loss: 0.2055 - accuracy: 0.9268 - val_loss: 0.2970 - val_accuracy: 0.8936
# Epoch 36/50
# 1719/1719 [==============================] - 2s 901us/step - loss: 0.2033 - accuracy: 0.9270 - val_loss: 0.3074 - val_accuracy: 0.8872
# Epoch 37/50
# 1719/1719 [==============================] - 2s 921us/step - loss: 0.1991 - accuracy: 0.9292 - val_loss: 0.2921 - val_accuracy: 0.8968
# Epoch 38/50
# 1719/1719 [==============================] - 2s 931us/step - loss: 0.1970 - accuracy: 0.9293 - val_loss: 0.2935 - val_accuracy: 0.8930
# Epoch 39/50
# 1719/1719 [==============================] - 2s 939us/step - loss: 0.1926 - accuracy: 0.9312 - val_loss: 0.2911 - val_accuracy: 0.8964
# Epoch 40/50
# 1719/1719 [==============================] - 2s 919us/step - loss: 0.1905 - accuracy: 0.9324 - val_loss: 0.3007 - val_accuracy: 0.8930
# Epoch 41/50
# 1719/1719 [==============================] - 2s 919us/step - loss: 0.1868 - accuracy: 0.9326 - val_loss: 0.3062 - val_accuracy: 0.8940
# Epoch 42/50
# 1719/1719 [==============================] - 2s 923us/step - loss: 0.1835 - accuracy: 0.9355 - val_loss: 0.2945 - val_accuracy: 0.8918
# Epoch 43/50
# 1719/1719 [==============================] - 2s 925us/step - loss: 0.1811 - accuracy: 0.9363 - val_loss: 0.2922 - val_accuracy: 0.8950
# Epoch 44/50
# 1719/1719 [==============================] - 2s 913us/step - loss: 0.1780 - accuracy: 0.9365 - val_loss: 0.3315 - val_accuracy: 0.8860
# Epoch 45/50
# 1719/1719 [==============================] - 2s 919us/step - loss: 0.1766 - accuracy: 0.9373 - val_loss: 0.3033 - val_accuracy: 0.8934
# Epoch 46/50
# 1719/1719 [==============================] - 2s 924us/step - loss: 0.1740 - accuracy: 0.9380 - val_loss: 0.2921 - val_accuracy: 0.8964
# Epoch 47/50
# 1719/1719 [==============================] - 2s 918us/step - loss: 0.1698 - accuracy: 0.9396 - val_loss: 0.2833 - val_accuracy: 0.8990
# Epoch 48/50
# 1719/1719 [==============================] - 2s 918us/step - loss: 0.1669 - accuracy: 0.9418 - val_loss: 0.3091 - val_accuracy: 0.8948
# Epoch 49/50
# 1719/1719 [==============================] - 2s 910us/step - loss: 0.1644 - accuracy: 0.9417 - val_loss: 0.3049 - val_accuracy: 0.8948
# Epoch 50/50
# 1719/1719 [==============================] - 2s 916us/step - loss: 0.1633 - accuracy: 0.9430 - val_loss: 0.3013 - val_accuracy: 0.8976

# %% [markdown]
# #### AVALIANDO MODELO

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.xlabel('epoch')
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 715us/step - loss: 0.3303 - accuracy: 0.8900
# [0.33026835322380066, 0.8899999856948853]

# %% [markdown]
# #### CLASSIFICANDO EXEMPLOS

# %%
X_new = X_test[:30]
y_pred = np.argmax(model.predict(X_new), axis=-1)

# %%
plt.figure(figsize=(10,10))
for i in range(30):
    plt.subplot(6,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_new[i], cmap=plt.cm.binary)
    plt.xlabel((class_names[y_test[i]]+'('+class_names[y_pred[i]]+')'))
plt.show()

# %%
cm = confusion_matrix(y_test,np.argmax(model.predict(X_test), axis=-1))

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=class_names)

plt.rcParams['figure.figsize'] = [15, 10]

disp.plot()

plt.show()
